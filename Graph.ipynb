# %% [markdown]
# <a href="https://colab.research.google.com/github/TrinaBan0807/python-starter-kit/blob/main/Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Sample data: Replace with your actual data
labels = ['Group A', 'Group B', 'Group C', 'Group D']
values = [45, 30, 15, 10]

# ---- Bar Graph ----
plt.figure(figsize=(8, 5))
plt.bar(labels, values, color='skyblue', edgecolor='black')
plt.title('Distribution Group (Bar Graph)')
plt.xlabel('Groups')
plt.ylabel('Number of Tickets')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# ---- Pie Chart ----
plt.figure(figsize=(6, 6))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title(' Distribution by Group (Pie Chart)')
plt.axis('equal')  # Equal aspect ratio ensures pie is a circle
plt.tight_layout()
plt.show()
