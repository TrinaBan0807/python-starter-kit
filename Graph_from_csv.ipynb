# %% [markdown]
# <a href="https://colab.research.google.com/github/TrinaBan0807/python-starter-kit/blob/main/Graph_from_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# %matplotlib inline

# %%
print("Please upload your file (.csv, .xls, .xlsx):")
uploaded = files.upload()

file_name = list(uploaded.keys())[0]
print("Uploaded file:", file_name)

# Determine file type
if file_name.endswith('.csv'):
    df = pd.read_csv(file_name)
elif file_name.endswith('.xls') or file_name.endswith('.xlsx'):
    df = pd.read_excel(file_name)
else:
    raise ValueError("Unsupported file type. Upload CSV or Excel.")
# Out:
# Please upload your file (.csv, .xls, .xlsx):
#      <input type="file" id="files-cc3ca860-2f41-44b9-a924-f2684b54456b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc3ca860-2f41-44b9-a924-f2684b54456b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
print("\nPreview of Uploaded Data:")
df.head()
# Out:
# Preview of Uploaded Data:
#       Name  Age      City Occupation                Email
# 0    Alice   30  New York   Engineer    alice@example.com
# 1      Bob   24    London   Designer      bob@example.com
# 2  Charlie   35     Paris     Doctor  charlie@example.com
# 3    David   29    Berlin     Artist    david@example.com
# 4      Eve   42     Tokyo     Writer      eve@example.com

# %%
print("\nAvailable columns:")
for col in df.columns:
    print("-", col)

x_column = input("\nEnter the column name for X-axis: ")
y_column = input("Enter the column name for Y-axis: ")

if x_column not in df.columns or y_column not in df.columns:
    raise ValueError("Column names do not exist in the file.")
# Out:
# Available columns:
# - Name
# - Age
# - City
# - Occupation
# - Email
#
# Enter the column name for X-axis: Name
# Enter the column name for Y-axis: Occupation

# %%
# Choose Graph Type

print("\nSelect Graph Type:")
print("1. Line Chart")
print("2. Bar Chart")
print("3. Scatter Plot")

choice = input("Enter choice (1/2/3): ")

plt.figure(figsize=(10, 6))

if choice == '1':
    plt.plot(df[x_column], df[y_column])
    plt.title("Line Chart")
elif choice == '2':
    plt.bar(df[x_column], df[y_column])
    plt.title("Bar Chart")
elif choice == '3':
    plt.scatter(df[x_column], df[y_column])
    plt.title("Scatter Plot")
else:
    raise ValueError("Invalid choice! Choose 1, 2, or 3.")

plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
plt.show()
# Out:
# Select Graph Type:
# 1. Line Chart
# 2. Bar Chart
# 3. Scatter Plot
# Enter choice (1/2/3): 2
